# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
numbers = [10, 20, 30, 40, 50]
numbers[1] = 25
print(numbers)
# Out:
# [10, 25, 30, 40, 50]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'cherry']

# %%
coordinates = (4.0, 5.0)
print(coordinates[0])
# Out:
# 4.0

# %%
colors = ("red", "green", "blue")
print(type(colors))
print(len(colors))
# Out:
# <class 'tuple'>
# 3

# %%
alphabet = ("a", "b", "c", "d")
alphabet_new = list(alphabet)
alphabet_new.append("e")
alphabet = tuple(alphabet_new)
print(alphabet)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
names = ("fulcrum",)
print(type(names))
# Out:
# <class 'tuple'>

# %%
car = {
    "brand" : "Ford",
    "model" : "Mustang",
    "year" : 1964
}
print(car)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
fruits_set = {"apple", "banana", "cherry"}
print(fruits_set)
fruits_set.add("apple")
print(fruits_set)
# Out:
# {'apple', 'cherry', 'banana'}
# {'apple', 'cherry', 'banana'}

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
set3 = set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 4, 5}

# %%
x = "100"
y = int(x)
y += 50
print(y)
# Out:
# 150

# %%
value = 10.75
value2 = int(value)
print(value2)
# Out:
# 10

# %%
my_list = [1, 2, 2, 3, 4, 4]
my_set = set(my_list)
print(my_set)
my_list = list(my_set)
print(my_list)
# Out:
# {1, 2, 3, 4}
# [1, 2, 3, 4]

# %%
number = input("Enter a number: ")
number2 = float(number) * 2
print(number2)
# Out:
# 6.0
