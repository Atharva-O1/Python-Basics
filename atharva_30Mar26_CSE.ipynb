# %%
tup_1 = ("a", "b", "c")
t_list = list(tup_1)
t_list.append("d")
tup_1 = tuple(t_list)
print(tup_1)
# Out:
# ('a', 'b', 'c', 'd')

# %%
names = ["aarsh", "aryan", "aryan", "atharva"]
dup_names = set(names)
print(dup_names)
names = list(dup_names)
print(names)
# Out:
# {'aryan', 'aarsh', 'atharva'}
# ['aryan', 'aarsh', 'atharva']

# %%
string1 = "250"
integer1 = int(string1)
print(type(integer1))
# Out:
# <class 'int'>

# %%
number = 99
float1 = float(number)
string1 = str(number)
print(float1)
print(string1)
# Out:
# 99.0
# 99

# %%
x = "45"
float1 = float(x)
integer1 = int(x)
print(float1)
print(integer1)
# Out:
# 45.0
# 45

# %%
boolean1 = False
integer1 = int(boolean1)
print(integer1)
# Out:
# 0

# %%
tup_1 = (10, 20, 30)
t_list = list(tup_1)
print(t_list)
# Out:
# [10, 20, 30]

# %%
list1 = [1, 2, 3, 4, 5]
print(list1[0])
print(list1[4])
print(len(list1))
# Out:
# 1
# 5
# 5

# %%
s = "MachineLearning"
print(s[0:7])
print(s[10:15])
# Out:
# Machine
# rning

# %%
names = ("faggot", "fishbed", "fulcrum", "felon")
names[1] = "falcon"
#this will give an error because tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 names = ("faggot", "fishbed", "fulcrum", "felon")
# ----> 2 names[1] = "falcon"
#
# TypeError: 'tuple' object does not support item assignment

# %%
lang = "python"
list1 = list(lang)
print(list1)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
nums = [5, 10, 15, 20]
nums.append(25)
print(nums)
nums.pop(1)
print(nums)
# Out:
# [5, 10, 15, 20, 25]
# [5, 15, 20, 25]

# %%
number1 = "6789"
list1 = list(number1)
print(list1)
# Out:
# ['6', '7', '8', '9']
