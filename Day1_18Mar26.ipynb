# %%
name = "Atharva"
age = 18
cgpa = 7.8
is_Student = True

print(name)
print(type(name))
print(age)
print(type(age))
print(cgpa)
print(type(cgpa))
print(is_Student)
print(type(is_Student))
# Out:
# Atharva
# <class 'str'>
# 18
# <class 'int'>
# 7.8
# <class 'float'>
# True
# <class 'bool'>

# %%
fruits = ["apple", "pineapple", "kiwi", "mango", "peach", "walnut"]
fruits.append("grapes")
fruits.append("strawberry")
fruits.append("orange")
print(fruits)
fruits.remove("walnut")
print(fruits)
fruits.extend({"dragonfruit", "watermelon"})
print(fruits)
# Out:
# ['apple', 'pineapple', 'kiwi', 'mango', 'peach', 'walnut', 'grapes', 'strawberry', 'orange']
# ['apple', 'pineapple', 'kiwi', 'mango', 'peach', 'grapes', 'strawberry', 'orange']
# ['apple', 'pineapple', 'kiwi', 'mango', 'peach', 'grapes', 'strawberry', 'orange', 'dragonfruit', 'watermelon']
