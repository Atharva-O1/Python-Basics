# %%
print(2**2)
print(11//2)
print(11%2)
# Out:
# 4
# 5
# 1

# %%
x = 10
print(x)
x += 10
print(x)
x -= 10
print(x)
x *= 10
print(x)
x /= 10
print(x)
# Out:
# 10
# 20
# 10
# 100
# 10.0

# %%
x = "word"
y = "word"
print(x > y)
print(x < y)
print(x == y)
print(x != y)
print("A" > "a")
# Out:
# False
# False
# True
# False
# False

# %%
x = 3
print(x <= 5 or x >= 1)
# Out:
# True

# %%
x = [2, 3, 4]
y = [2, 3, 4]
z = 2
print(x is z)
print(y == z)
# Out:
# False
# False

# %%
x = 400
if x > 100:
    if(x % 2 == 0):
        print("Even")
    else:
        print("Odd")
    print("Value is greater than 100")
else:
    print("Value is less than 100")
# Out:
# Even
# Value is greater than 100
